# %% [markdown]
# ### Conditional Statements in Python
#
#     Conditional statements in Python are used to execute certain blocks of code based on specific conditions. These statements help control the flow of a program, making it behave differently in different situations.

# %% [markdown]
# #### If Conditional Statement:-
#
#     If statement is the simplest form of a conditional statement. It executes a block of code if the given condition is `true.`

# %%
age = 20
if age >= 18:
    print("Eligible to vote.")
# Out:
# Eligible to vote.

# %%
# Short Hand if:- Short-hand if statement allows us to write a single-line if statement.
user_age = int(input('Hey folk what is your age:- '))
if user_age >= 18: print('your become a adult')
# Out:
# Hey folk what is your age:-  4

# %% [markdown]
# #### If else Conditional Statement
#
#     If Else allows us to specify a block of code that will execute if the condition(s) associated with an if or elif statement evaluates to False. Else block provides a way to handle all other cases that don't meet the specified conditions.

# %%
age = 10
if age <= 12:
    print("Travel for free.")
else:
    print("Pay for ticket.")
# Out:
# Travel for free.

# %%
# Short Hand if-else:- The short-hand if-else statement allows us to write a single-line if-else statement.
marks = 45
res = "Pass" if marks >= 40 else "Fail"
print(f"Result: {res}")
# Out:
# Result: Pass

# %% [markdown]
#     Note: This method is also known as ternary operator. Ternary Operator essentially a shorthand for the if-else statement that allows us to write more compact and readable code, especially for simple conditions.

# %%
age = 25

if age <= 12:
    print("Child.")
elif age <= 19:
    print("Teenager.")
elif age <= 35:
    print("Young adult.")
else:
    print("Adult.")
# Out:
# Young adult.

# %% [markdown]
# #### Nested if..else Conditional Statement
#
#     Nested if..else means an if-else statement inside another if statement. We can use nested if statements to check conditions within conditions.
# ![image.png](attachment:2d596087-a3a4-4f83-9d1e-a8f6a91ee959.png)!

# %%
age = 61
is_member = True

if age >= 60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")
else:
    print("Not eligible for a senior discount.")
# Out:
# 30% senior discount!

# %% [markdown]
# #### Ternary Conditional Statement
#
#     A ternary conditional statement is a compact way to write an if-else condition in a single line. It’s sometimes called a "conditional expression."

# %%
# Assign a value based on a condition
age = 2_00
s = "Adult" if age >= 18 else "Minor"
print(s)
# Out:
# Adult

# %%
threshold_value = 1.7
s = '+ ve value prediction' if threshold_value >= 1.7 else '- ve side prediction'
print(s)
# Out:
# + ve value prediction

# %% [markdown]
# `Ternary Operator in Python`
#
#     The ternary operator in Python perform conditional checks and assign values or execute expressions in a single line. It is also known as a conditional expression because it evaluates a condition and returns one value if the condition is True and another if it is False.

# %%
n = int(input('enter a number:- '))
res = "Even" if n % 2 == 0 else "Odd"
print(res)
# Out:
# enter a number:-  8
# Even

# %%
# Ways to Use Ternary Operator
""" 1. Nested If else:- The ternary operator can also be used in Python nested if-else statement. We can nest ternary operators to evaluate multiple 
conditions in a single line."""

n = -5

res = "Positive" if n > 0 else "Negative" if n < 0 else "Zero"
print(res)
# Out:
# Negative

# %%
"""2. Using Tuple:- The ternary operator can also be written by using Python tuples. The tuple indexing method is an alternative to the ternary 
operator."""
n = 7
res = ("Odd", "Even")[n % 2 == 0]
print(res)
# Out:
# Odd

# %%
age = int(input('enter a number: '))
res = ('Teenager', 'not a teenager') [age >18]
res
# Out:
# enter a number:  18
# 'Teenager'

# %%
"""3. Using Dictionary:- A dictionary can be used to map conditions to values, providing a way to use a ternary operator with more complex conditions.
Syntax:
condition_dict = {True: value_if_true, False: value_if_false}"""

a = 10
b = 20
m1 = {True: a, False: b}[a > b]
print(m1)
# Out:
# 20

# %%
# 4. Using Python Lambda:- Lambdas can be used in conjunction with the ternary operator for inline conditional logic.

a = 10
b = 20
m1 = (lambda x, y: x if x > y else y)(a, b)
print(m1)
# Out:
# 20

# %%
# 5. Using Print Function:- The ternary operator can also be directly used with the Python print statement.
# Syntax: print(value_if_true if condition else value_if_false)

a = 10
b = 20

print("a is greater" if a > b else "b is greater")
# Out:
# b is greater

# %%
"""Limitations of Python Ternary Operator
While the ternary operator is concise, it should be used with caution:

It can reduce readability if overused or used in complex conditions.
It's limited to simple, single-line expressions."""
# Out:
# "Limitations of Python Ternary Operator\nWhile the ternary operator is concise, it should be used with caution:\n\nIt can reduce readability if overused or used in complex conditions.\nIt's limited to simple, single-line expressions."

# %% [markdown]
# #### Python - if, if-else, Nested if and if-elif Statements
#
#     In python conditional statements help control the flow of a program by executing different blocks of code based on whether a condition is true or false. These statements allow decision-making in code. The main types of conditional statements are:
#
#     - if
#     - if-else
#     - nested if
#     - if-elif

# %% [markdown]
# ##### if Statement
#     An if statement is used when a block of code needs to be executed only if a specific condition evaluates to True.

# %%
if 10 > 5:
    print("10 greater than 5")
print("Program ended")
# Out:
# 10 greater than 5
# Program ended

# %% [markdown]
# ##### if else Statement
#
#     In conditional if Statement the additional block of code is merged as else statement which is performed when if condition is false.
#
#     In Python, If-Else is a fundamental conditional statement used for decision-making in programming. If...Else statement allows to execution of specific blocks of code depending on the condition is True or False.

# %%
# Simple if

i = 10

# Checking if i is greater than 15
if i > 15:
    print("10 is less than 15")
    
print("I am Not in if")
# Out:
# I am Not in if

# %%
# Simple if-else
i = 20

 # Checking if i is greater than 0
if i > 0:
    print("i is positive")
else:
    print("i is 0 or Negative")
# Out:
# i is positive

# %%
# If Else in One-line
a = -2

# Ternary conditional to check if number is positive or negative
res = "Positive" if a >= 0 else "Negative"
print(res)
# Out:
# Negative

# %%
# Logical Operators with If..Else
age = 25
exp = 10

# Using '>' operator & 'and' with if-else
if age > 23 and exp > 8:
    print("Eligible.")
else:
    print("Not eligible.")
# Out:
# Eligible.

# %% [markdown]
# ![image.png](attachment:619fec87-bf35-4c4e-a4a3-a4af2b0ee241.png)

# %%
"""# Nested If Else Statement
Nested if...else statement occurs when if...else structure is placed inside another if or else block. Nested If..else allows the execution of specific
code blocks based on a series of conditional checks"""


i = 10
if i == 10:
 
    #  First if statement
    if i < 15:
        print("i is smaller than 15")
        
    # Nested - if statement
    # Will only be executed if statement above
    # it is true
    if i < 12:
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")
else:
  print("i is not equal to 10")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
""" if…elif…else Statement
if-elif-else statement in Python is used for multi-way decision-making. This allows us to check multiple conditions sequentially and execute a 
specific block of code when a condition is True. If none of the conditions are true, the else block is executed."""

i = 25

 # Checking if i is equal to 10
if i == 10:
    print("i is 10")
 # Checking if i is equal to 15

elif i == 15:
    print("i is 15")
 # Checking if i is equal to 20

elif i == 20:
    print("i is 20")
    
 # If none of the above conditions are true
else:
    print("i is not present")
# Out:
# i is not present

# %% [markdown]
# ##### Nested if Statement
#
#     if statement can also be checked inside other if statement. This conditional statement is called a nested if statement. This means inner if condition will only be checked if the outer if condition is True.
#
#     A nested if statement in Python is an if statement located within another if or else clause. This nesting can continue with multiple layers, allowing programmers to evaluate multiple conditions sequentially. It's particularly useful in scenarios where multiple criteria need to be checked before taking an action.

# %%
a = 10
if a > 5:
    print("Bigger than 5")
    if a <= 15:
        print("Between 5 and 15")
# Out:
# Bigger than 5
# Between 5 and 15

# %%
age = 30
member = True

if age > 18:
    if member:
        print("Ticket price is $12.")
    else:
        print("Ticket price is $20.")
else:
    if member:
        print("Ticket price is $8.")
    else:
        print("Ticket price is $10.")
# Out:
# Ticket price is $12.

# %%
# Nested if with else Condition
i = 0; 

# if condition 1
if i != 0:
    # condition 1
    if i > 0:
        print("Positive")
        
    # condition 2
    if i < 0:
        print("Negative")
else:
    print("Zero")
# Out:
# Zero

# %% [markdown]
# ##### if-elif Statement
#
#     The if-elif statement is a shortcut for chaining multiple if-else conditions. While using if-elif statement at the end else block is added which is performed if none of the above if-elif statement is true.

# %%
letter = "A"
if letter == "B":
    print("letter is B")
elif letter == "C":
    print("letter is C")
elif letter == "A":
    print("letter is A")
else:
    print("letter isn't A, B or C")
# Out:
# letter is A

# %% [markdown]
# #### Match-Case Statement
#     match-case statement is Python's version of a switch-case found in other languages. It allows us to match a variable's value against a set of patterns.
#     the match case statement offers a powerful mechanism for pattern matching in Python. It allows us to perform more expressive and readable conditional checks.
#
#      Unlike traditional if-elif-else chains, which can become unwieldy with complex conditions, the match-case statement provides a more elegant and flexible solution.
#
#
# match-case is a cleaner and more powerful alternative to multiple if-elif statements, especially useful for matching object types and extracting their data.

# %%
def check_number(x):
    match x:
        case 10:
            print('I am the 10 th checking case')
        case 20:
            print('I am the 20 th checking case')
        case _:
            print('None of these cases')
check_number(0)
# Out:
# None of these cases

# %% [raw]
# syntax:-
# match subject:
#     case pattern1:
#         # Code block if pattern1 matches
#     case pattern2:
#         # Code block if pattern2 matches
#     case _:
#         # Default case (wildcard) if no other pattern matches
#
# match subject: The value (or variable) to match against.
# case pattern: A pattern to match the subject.
# _ (Wildcard): A default catch-all pattern, similar to a "default" in other languages' switch statements.

# %%
"""
Match Case Statements with Constants
Matching constants is one of the simplest uses of the match-case statement. It checks if a variable matches specific constant values and allows for 
different actions based on the matched constant.
"""

def greet(person):
    match person:
        case "A":
            print("Hello, A!")
        case "B":
            print("Hello, B!")
        case _:
            print("Hello, stranger!")

greet("A")
greet("B")
# Out:
# Hello, A!
# Hello, B!

# %%
# Match Case Statement with OR Operator?
def num_check(x):
    match x:
        case 10 | 20 | 30:  # Matches 10, 20, or 30
            print(f"Matched: {x}")
        case _:
            print("No match found")

num_check(10)
num_check(20)
num_check(25)
# Out:
# Matched: 10
# Matched: 20
# No match found

# %%
# Match Case Statement with Python If Condition
def num_check(x):
    match x:
        case 10 if x % 2 == 0:  # Match 10 only if it's even
            print("Matched 10 and it's even!")
        case 10:
            print("Matched 10, but it's not even.")
        case _:
            print("No match found")

num_check(10)
num_check(15)
# Out:
# Matched 10 and it's even!
# No match found

# %%
# Match Case Statement on Sequences
def process(data):
    match data:
        case [x, y]:  
          	# A list with two elements
            print(f"Two-element list: {x}, {y}")
        case [x, y, z]:  
          	# A list with three elements
            print(f"Three-element list: {x}, {y}, {z}")
        case _:
            print("Unknown data format")

process([1, 2])
process([1, 2, 3])
process([1, 2, 3, 4])
# Out:
# Two-element list: 1, 2
# Three-element list: 1, 2, 3
# Unknown data format

# %%
# Match Case Statement on Mappings (Dictionaries)
# A mapping is another common data type in Python and match-case can be used to match against dictionaries, checking for specific keys and values.
def person(person):
    match person:
      
      	# Dictionary with name and age keys
        case {"name": name, "age": age}:  
            print(f"Name: {name}, Age: {age}")
            
        # Dictionary with only name key    
        case {"name": name}:  
            print(f"Name: {name}")
        case _:
            print("Unknown format")

person({"name": "Alice", "age": 25})
person({"name": "Bob"})
person({"city": "New York"})
# Out:
# Name: Alice, Age: 25
# Name: Bob
# Unknown format

# %%
# Match Case Statement with Python Class
"""One of the most powerful features of match-case is the ability to match against classes. We can match instances of a class and even extract 
specific attributes of an object for further handling."""

class Shape:
    pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

def check_shape(one):
    match one:
      
      	# Match Circle and extract the radius
        case Circle(radius=r) if r>5:  
            print(f"circle radius {r}.")
        # # the above It is almost equal to
        # if isinstance(shape, Circle):
        #     r = shape.radius
            
        # Match Rectangle and extract width and height
        case Rectangle(width=w, height=h):  
            print(f"Rectangle width {w} and height {h}.")
            
        # Default case for any other object
        case _:  
            print("This is an unknown shape.")

# Create objects of Circle and Rectangle
circle = Circle(15)
rectangle = Rectangle(4, 6)

# Test with different shapes
check_shape(circle)     
check_shape(rectangle)
# Out:
# circle radius 15.
# Rectangle width 4 and height 6.

# %% [markdown]
#     If I can use isinstance(), why should I use match-case?
#
# Use isinstance() when:
#
#     You only need to check the type.
#
# Use match-case when:
#
#     You want to check type and
#     Extract attributes and
#     Possibly add conditions
#     Or match complex structures
#
# ✅ Checks the object type
# ✅ Extracts attributes (if matched)
#
#     1️⃣ Takes the object
#     2️⃣ Checks → isinstance(shape, Circle)
#     3️⃣ If True → reads shape.radius
#     4️⃣ Stores value into r
#     5️⃣ Executes block

# %%
# Without match:
s = Shape()
check_shape(s)
if isinstance(s, Circle):
    print(shape.radius)

elif isinstance(s, Rectangle):
    print(shape.width, shape.height)

else:
    print("Unknown")
# Out:
# This is an unknown shape.
# Unknown

# %%
shape = Shape()
check_shape(s)
match shape:
    case Circle(radius=r):
        ...
# Out:
# This is an unknown shape.

# %%
user_input = int(input('Enter a number'))
res = 1
for i in range(1, user_input+1):
    res = res * i
print(res)
# Out:
# Enter a number 10
# 3628800

# %%
n = int(input('enter a number'))
a = 1
b = 1
while a <= n:
    b = b *a
    a += 1

print(a)
print(b)
# Out:
# enter a number 5
# 6
# 120

# %%
n = 13
m = 4
if n % m == 1:
    print('12 is the Closest Number to 13 which is divisible by 4.')
# Out:
# 12 is the Closest Number to 13 which is divisible by 4.

# %%
class Solution:
    def closestNumber(self, n, m):
        print(f"The values of N: '{n}' and M:- '{m}'")
        if n==m:
            return n
        if m== 0:
            return
        
        quot = n//m #floor division operator rounds off to lowest
        print('quot number:-', quot)
       
       # if n or m is -ve or both are -ve or both are +ve
        low = m * quot
        high = m* (quot+1)
        print(f"the values of low value is:- '{low}' and high value is:- '{high}'")
        
        #finding nearest num to n among low and high
        if(abs(n-low)< abs(n-high)): 
            return low
        elif(abs(n-low)> abs(n-high)):
            return high
        
        else:
            if(abs(low)>abs(high)):#abs(high) can never be equal to abd(low)
                return low
            else:
                return high

# %%
s = Solution()

# %%
s.closestNumber(5,3)
# Out:
# The values of N: '5' and M:- '3'
# quot number:- 1
# the values of low value is:- '3' and high value is:- '6'
# 6

# %%
def check_Even_Number(n):
    match n:
        case n if n % 2 ==0:
            print('Even Number')
        case _:
            print('Not  a even number')
n = int(input('Enter a Number'))
check_Even_Number(n)
# Out:
# Enter a Number 9
# Not  a even number

# %%
['Even' if int(input()) %2 == 0 else 'odd']
# Out:
#  5
# ['odd']

# %%
# greatest of three
a = 1
b = 2
c = 3
max(a,b,c)
# Out:
# 3

# %%
def gretestOfThree(data):
    match data:
        case (a,b,c) if a >= b and a>=c:
            print(a)
        case (a,b,c) if b>=a and b>=c:
            print(b)
        case (a,b,c):
            print(c)

a,b,c = 1,2,3
data = (a,b,c)
gretestOfThree(data)
# Out:
# 3

# %%
num = int(input('Enter a  Number'))

count = 0 
for i in range(1, num+1):
    if num % i == 0:
        count+=1
if count == 2:
    print('Prime')
else:
    print('not prime')
# Out:
# Enter a  Number 7
# Prime

# %%
# F(n) = F(n-1) + F(n-2), F(0)= 0, F(1)=1
def fibnocii(n):
    a = 0
    b = 1
    return [n-1]+[n-2]

# %%
def fib(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fib(n-1)+fib(n-2)
n = int(input())
print(fib(n))
# Out:
#  9
# 34

# %%
n = int(input())
if n == 0:
    print(0)
elif n == 1:
    print(1)
else:
    a, b = 0, 1
    print('Intial %d, %d'%(a,b))
    for i in range(2, n + 1):
        print('looping number currently %d'%i)
        a, b = b, a + b
        print('After loop in the %d %d' %(a,b))
    print(b)
# Out:
#  5
# Intial 0, 1
# looping number currently 2
# After loop in the 1 1
# looping number currently 3
# After loop in the 1 2
# looping number currently 4
# After loop in the 2 3
# looping number currently 5
# After loop in the 3 5
# 5
